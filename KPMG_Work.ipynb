# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xls = pd.ExcelFile('KPMG_VI_New_raw_data_update_final.xlsx')
trans = pd.read_excel(xls, 'Transactions',skiprows=1)
newcust = pd.read_excel(xls, 'NewCustomerList',skiprows=1)
custdemo = pd.read_excel(xls, 'CustomerDemographic',skiprows=1)
custadd = pd.read_excel(xls, 'CustomerAddress',skiprows=1)

# %%
trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved   Trek Bicycles     Standard        medium        large  ...
# 2     Approved      OHM Cycles     Standard           low       medium  ...
# 3     Approved  Norco Bicycles     Standard        medium       medium  ...
# 4     Approved  Giant Bicycles     Standard        medium        large  ...
#
# ...

# %%
trans[trans.duplicated()]
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Unnamed: 21, Unnamed: 22, Unnamed: 23, Unnamed: 24, Unnamed: 25]
# Index: []
#
# [0 rows x 26 columns]

# %%
newcust.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
newcust[newcust.duplicated()]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Rank, Value]
# Index: []
#
# [0 rows x 23 columns]

# %%
custdemo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  ...  \
# 0                Health      Mass Customer                  N  ...
# 1    Financial Services      Mass Customer                  N  ...
# ...

# %%
custadd.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0                  10         NaN         NaN         NaN         NaN  ...
# 1                  10         NaN         NaN         NaN         NaN  ...
# 2                   9         NaN         NaN         NaN         NaN  ...
# 3                   4         NaN         NaN         NaN         NaN  ...
# 4                   9         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# ...

# %%
custadd[custadd.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Unnamed: 21, Unnamed: 22, Unnamed: 23, Unnamed: 24, Unnamed: 25]
# Index: []
#
# [0 rows x 26 columns]

# %%
# result = pd.merge(left, right, how="inner", on=["key1", "key2"])

# %%
custdemo.isnull().sum()
# Out:
# customer_id                               0
# first_name                                0
# last_name                               125
# gender                                    0
# past_3_years_bike_related_purchases       0
# DOB                                      87
# job_title                               506
# job_industry_category                   656
# wealth_segment                            0
# deceased_indicator                        0
# default                                 302
# owns_car                                  0
# tenure                                   87
# Unnamed: 13                            4000
# Unnamed: 14                            4000
# Unnamed: 15                            4000
# Unnamed: 16                            4000
# Unnamed: 17                            4000
# Unnamed: 18                            4000
# Unnamed: 19                            4000
# Unnamed: 20                            4000
# ...

# %%
custdemo[custdemo.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, default, owns_car, tenure, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Unnamed: 21, Unnamed: 22, Unnamed: 23, Unnamed: 24, Unnamed: 25]
# Index: []
#
# [0 rows x 26 columns]

# %%
custdemo["Date"]=pd.to_datetime(custdemo["DOB"])
custdemo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  ...  \
# 0                Health      Mass Customer                  N  ...
# 1    Financial Services      Mass Customer                  N  ...
# ...

# %%
custdemo.sort_values(by="Date")
# Out:
#       customer_id first_name  last_name  gender  \
# 33             34   Jephthah   Bachmann       U
# 719           720     Darrel      Canet    Male
# 1091         1092     Katlin    Creddon  Female
# 3409         3410    Merrili    Brittin  Female
# 2412         2413      Abbey     Murrow    Male
# ...           ...        ...        ...     ...
# 3778         3779      Ulick     Daspar       U
# 3882         3883      Nissa     Conrad       U
# 3930         3931      Kylie      Epine       U
# 3934         3935     Teodor  Alfonsini       U
# 3997         3998     Sarene    Woolley       U
#
#       past_3_years_bike_related_purchases        DOB  \
# 33                                     59 1843-12-21
# 719                                    67 1931-10-23
# 1091                                   56 1935-08-22
# 3409                                   93 1940-09-22
# 2412                                   27 1943-08-11
# ...                                   ...        ...
# ...

# %%
custdemo.shape
# Out:
# (4000, 27)

# %%
trans.shape
# Out:
# (20000, 26)

# %%
trans.isnull().sum()
# Out:
# transaction_id                 0
# product_id                     0
# customer_id                    0
# transaction_date               0
# online_order                 360
# order_status                   0
# brand                        197
# product_line                 197
# product_class                197
# product_size                 197
# list_price                     0
# standard_cost                197
# product_first_sold_date      197
# Unnamed: 13                20000
# Unnamed: 14                20000
# Unnamed: 15                20000
# Unnamed: 16                20000
# Unnamed: 17                20000
# Unnamed: 18                20000
# Unnamed: 19                20000
# Unnamed: 20                20000
# Unnamed: 21                20000
# Unnamed: 22                20000
# Unnamed: 23                20000
# Unnamed: 24                20000
# Unnamed: 25                20000
# dtype: int64

# %%
custadd.isnull().sum()
# Out:
# customer_id              0
# address                  0
# postcode                 0
# state                    0
# country                  0
# property_valuation       0
# Unnamed: 6            3999
# Unnamed: 7            3999
# Unnamed: 8            3999
# Unnamed: 9            3999
# Unnamed: 10           3999
# Unnamed: 11           3999
# Unnamed: 12           3999
# Unnamed: 13           3999
# Unnamed: 14           3999
# Unnamed: 15           3999
# Unnamed: 16           3999
# Unnamed: 17           3999
# Unnamed: 18           3999
# Unnamed: 19           3999
# Unnamed: 20           3999
# Unnamed: 21           3999
# Unnamed: 22           3999
# Unnamed: 23           3999
# Unnamed: 24           3999
# Unnamed: 25           3999
# dtype: int64

# %%
2022-1843
# Out:
# 179

# %%
result = pd.merge(trans, custdemo, how="inner", on=["customer_id"])
result.shape
# Out:
# (19997, 52)

# %%
result.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
# ...

# %%
result1 = pd.merge(result, custadd, how="inner", on=["customer_id"])
result1.shape
# Out:
# (19968, 77)

# %%
result1.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'Unnamed: 13_x', 'Unnamed: 14_x',
#        'Unnamed: 15_x', 'Unnamed: 16_x', 'Unnamed: 17_x', 'Unnamed: 18_x',
#        'Unnamed: 19_x', 'Unnamed: 20_x', 'Unnamed: 21_x', 'Unnamed: 22_x',
#        'Unnamed: 23_x', 'Unnamed: 24_x', 'Unnamed: 25_x', 'first_name',
#        'last_name', 'gender', 'past_3_years_bike_related_purchases', 'DOB',
#        'job_title', 'job_industry_category', 'wealth_segment',
#        'deceased_indicator', 'default', 'owns_car', 'tenure', 'Unnamed: 13_y',
#        'Unnamed: 14_y', 'Unnamed: 15_y', 'Unnamed: 16_y', 'Unnamed: 17_y',
#        'Unnamed: 18_y', 'Unnamed: 19_y', 'Unnamed: 20_y', 'Unnamed: 21_y',
#        'Unnamed: 22_y', 'Unnamed: 23_y', 'Unnamed: 24_y', 'Unnamed: 25_y',
# ...

# %%
result1.drop(['Unnamed: 13_x', 'Unnamed: 14_x',
       'Unnamed: 15_x', 'Unnamed: 16_x', 'Unnamed: 17_x', 'Unnamed: 18_x',
       'Unnamed: 19_x', 'Unnamed: 20_x', 'Unnamed: 21_x', 'Unnamed: 22_x',
       'Unnamed: 23_x', 'Unnamed: 24_x', 'Unnamed: 25_x','Unnamed: 13_y',
       'Unnamed: 14_y', 'Unnamed: 15_y', 'Unnamed: 16_y', 'Unnamed: 17_y',
       'Unnamed: 18_y', 'Unnamed: 19_y', 'Unnamed: 20_y', 'Unnamed: 21_y',
       'Unnamed: 22_y', 'Unnamed: 23_y', 'Unnamed: 24_y', 'Unnamed: 25_y',
        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
       'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
       'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
       'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],axis=1,inplace=True)

# %%
result1.shape
# Out:
# (19968, 31)

# %%
result1.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
# ...

# %%
result1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19968 entries, 0 to 19967
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       19968 non-null  int64
#  1   product_id                           19968 non-null  int64
#  2   customer_id                          19968 non-null  int64
#  3   transaction_date                     19968 non-null  datetime64[ns]
#  4   online_order                         19609 non-null  float64
#  5   order_status                         19968 non-null  object
#  6   brand                                19773 non-null  object
#  7   product_line                         19773 non-null  object
#  8   product_class                        19773 non-null  object
#  9   product_size                         19773 non-null  object
#  10  list_price                           19968 non-null  float64
# ...

# %%
result1.nunique()
# Out:
# transaction_id                         19968
# product_id                               101
# customer_id                             3489
# transaction_date                         364
# online_order                               2
# order_status                               2
# brand                                      6
# product_line                               4
# product_class                              3
# product_size                               3
# list_price                               294
# standard_cost                            100
# product_first_sold_date                  100
# first_name                              2835
# last_name                               3263
# gender                                     6
# past_3_years_bike_related_purchases      100
# DOB                                     3047
# job_title                                195
# job_industry_category                      9
# wealth_segment                             3
# ...

# %%
result1.skew(skipna = True)
# Out:
# transaction_id                         0.000584
# product_id                             0.081898
# customer_id                            0.008573
# online_order                          -0.002754
# list_price                            -0.126073
# standard_cost                          0.863855
# product_first_sold_date               -0.113428
# past_3_years_bike_related_purchases    0.059059
# tenure                                 0.044641
# postcode                               0.626183
# property_valuation                    -0.643455
# dtype: float64

# %%
result1.isnull().sum().sort_values(ascending = False)*100 / result1.shape[0]
# Out:
# job_industry_category                  16.135817
# job_title                              11.914062
# default                                 7.266627
# last_name                               3.215144
# tenure                                  2.233574
# DOB                                     2.233574
# Date                                    2.233574
# online_order                            1.797877
# brand                                   0.976562
# product_line                            0.976562
# product_class                           0.976562
# product_size                            0.976562
# standard_cost                           0.976562
# product_first_sold_date                 0.976562
# owns_car                                0.000000
# transaction_id                          0.000000
# deceased_indicator                      0.000000
# postcode                                0.000000
# state                                   0.000000
# ...

# %%
duplicate = result1[result1.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, default, owns_car, tenure, Date, address, postcode, state, country, property_valuation]
# Index: []
#
# [0 rows x 31 columns]

# %%
for col in result1.columns:
    print(col, "has", result1[col].nunique() , " unique values, those are:")
    print(result1[col].unique())
    print()
# Out:
# transaction_id has 19968  unique values, those are:
# [    1 11065 18923 ... 18462 17981 18165]
#
# product_id has 101  unique values, those are:
# [  2   1  62   3   4  91  95  38  41  10  37  47  12  61  77  88  59  98
#   73  71  78  54  83  40  45  22  31  39  23  25  60  53  90  16  68  29
#   69  28  55  15  50   0  30  99  14   5  96  67  81  21  84   8  19  79
#   18   6  89  56  86  42  80  51  35  11  44  32  66  57  33  26  58  48
#   65  74  43  27  17  64  82  34  72   7  49  36  70  76  97  92  63  46
#    9  93  94  20  87  13  85 100  75  52  24]
#
# customer_id has 3489  unique values, those are:
# [2950 3120  402 ...  130 2789 3446]
#
# transaction_date has 364  unique values, those are:
# ['2017-02-25T00:00:00.000000000' '2017-10-16T00:00:00.000000000'
#  '2017-04-26T00:00:00.000000000' '2017-05-21T00:00:00.000000000'
#  '2017-10-05T00:00:00.000000000' '2017-10-30T00:00:00.000000000'
#  '2017-01-30T00:00:00.000000000' '2017-01-20T00:00:00.000000000'
# ...

# %%
result1["gender"].value_counts().plot(kind="bar")

# %%
result1["gender"].value_counts()
# Out:
# Female    9979
# Male      9510
# U          455
# F           11
# Femal        7
# M            6
# Name: gender, dtype: int64

# %%
d_gender = {
    'Female':'Female',
    'Male':'Male',
    'F':'Female',
    'Femal':'Female',
    'M':'Male',
    'U':'Undisclosed'
}

# %%
col_to_be_changed = ["gender"]
changed_name = [d_gender]

for column,change in zip(col_to_be_changed,changed_name):
    print(column)
    print(change)
    result1[column] = result1[column].replace(change)
# Out:
# gender
# {'Female': 'Female', 'Male': 'Male', 'F': 'Female', 'Femal': 'Female', 'M': 'Male', 'U': 'Undisclosed'}

# %%
result1["gender"].value_counts().plot(kind="bar")

# %%
result1.to_csv('file1.csv')

# %%
result1["country"].value_counts().plot(kind="bar")

# %%
result1["owns_car"].value_counts().plot(kind="bar")

# %%
result1["wealth_segment"].value_counts().plot(kind="bar")

# %%
result1["job_industry_category"].value_counts().plot(kind="bar")

# %%
result1["job_title"].value_counts()
# Out:
# Social Worker                           226
# Legal Assistant                         221
# Business Systems Development Analyst    221
# Assistant Professor                     212
# Executive Secretary                     208
#                                        ...
# Administrative Assistant I               15
# Health Coach III                         14
# Geologist II                             11
# Research Assistant III                    9
# Developer I                               7
# Name: job_title, Length: 195, dtype: int64

# %%
result1["online_order"].value_counts().plot(kind="bar")

# %%
result1["brand"].value_counts().plot(kind="bar")

# %%
result1.describe().transpose()
# Out:
#                                        count          mean          std  \
# transaction_id                       19968.0   9997.846504  5773.929973
# product_id                           19968.0     45.365986    30.750115
# customer_id                          19968.0   1740.254307  1009.819066
# online_order                         19609.0      0.500688     0.500012
# list_price                           19968.0   1107.780004   582.852548
# standard_cost                        19773.0    556.091050   405.966472
# product_first_sold_date              19773.0  38198.741364  2874.856871
# past_3_years_bike_related_purchases  19968.0     48.757412    28.611359
# tenure                               19522.0     10.681949     5.674631
# postcode                             19968.0   2987.623347   851.306647
# property_valuation                   19968.0      7.516376     2.824783
#
#                                           min       25%       50%       75%  \
# ...

# %%
result1["product_class"].value_counts().plot(kind="bar")

# %%
result1["product_size"].value_counts().plot(kind="bar")

# %%
result1["state"].value_counts().plot(kind="bar")

# %%
result1["property_valuation"].value_counts().plot(kind="bar")

# %%
result1["tenure"].value_counts().plot(kind="bar")

# %%
ax=sns.countplot(data = result1,x="job_industry_category",hue = "gender")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
result1.groupby(["brand"])["list_price"].mean().reset_index().sort_values(by=["list_price"],ascending = False)
# Out:
#             brand   list_price
# 5        WeareA2B  1262.827161
# 0  Giant Bicycles  1235.576276
# 4   Trek Bicycles  1183.683641
# 3           Solex  1057.643074
# 2      OHM Cycles   983.972290
# 1  Norco Bicycles   913.346017

# %%
result1.groupby(["brand"])["standard_cost"].mean().reset_index().sort_values(by=["standard_cost"],ascending = False)
# Out:
#             brand  standard_cost
# 0  Giant Bicycles     760.236212
# 1  Norco Bicycles     615.312916
# 4   Trek Bicycles     568.505474
# 2      OHM Cycles     496.679622
# 3           Solex     489.870313
# 5        WeareA2B     427.663413

# %%
result1["profit"] = result1["list_price"]-result1["standard_cost"]

# %%
result1.groupby(["brand"])["profit"].mean().reset_index().sort_values(by=["profit"],ascending = False)
# Out:
#             brand      profit
# 5        WeareA2B  835.163748
# 4   Trek Bicycles  615.178166
# 3           Solex  567.772761
# 2      OHM Cycles  487.292669
# 0  Giant Bicycles  475.340063
# 1  Norco Bicycles  298.033102

# %%
result1.groupby(["wealth_segment"])["profit"].mean().reset_index().sort_values(by=["profit"],ascending = False)
# Out:
#       wealth_segment      profit
# 0  Affluent Customer  556.759017
# 2      Mass Customer  551.204580
# 1     High Net Worth  548.837992

# %%
result1.groupby(["wealth_segment"])["list_price"].mean().reset_index().sort_values(by=["list_price"],ascending = False)
# Out:
#       wealth_segment   list_price
# 0  Affluent Customer  1111.864397
# 2      Mass Customer  1108.855412
# 1     High Net Worth  1101.752204

# %%
result1.groupby(["job_industry_category"])["profit"].mean().reset_index().sort_values(by=["profit"],ascending = False)
# Out:
#   job_industry_category      profit
# 4                    IT  567.338283
# 7                Retail  562.434914
# 2    Financial Services  560.536210
# 1         Entertainment  556.353674
# 6              Property  547.839789
# 5         Manufacturing  545.200744
# 3                Health  542.676710
# 0           Argiculture  535.320406
# 8    Telecommunications  532.386392

# %%
result1.groupby(["job_industry_category"])["list_price"].mean().reset_index().sort_values(by=["list_price"],ascending = False)
# Out:
#   job_industry_category   list_price
# 7                Retail  1126.935910
# 4                    IT  1124.998717
# 1         Entertainment  1123.621261
# 2    Financial Services  1114.165227
# 6              Property  1106.558759
# 5         Manufacturing  1105.476697
# 3                Health  1103.346802
# 0           Argiculture  1068.086453
# 8    Telecommunications  1059.988701

# %%
result1.groupby(["state"])["list_price"].mean().reset_index().sort_values(by=["list_price"],ascending = False)
# Out:
#              state   list_price
# 2              QLD  1119.109240
# 3              VIC  1113.668934
# 0              NSW  1103.993488
# 4         Victoria  1095.295458
# 1  New South Wales  1045.075278

# %%
result1.groupby(["state"])["profit"].mean().reset_index().sort_values(by=["profit"],ascending = False)
# Out:
#              state      profit
# 3              VIC  560.438567
# 2              QLD  554.669931
# 0              NSW  549.189432
# 4         Victoria  531.487683
# 1  New South Wales  526.799604

# %%
result1.groupby(["product_class"])["list_price"].mean().reset_index().sort_values(by=["list_price"],ascending = False)
# Out:
#   product_class   list_price
# 2        medium  1150.239181
# 0          high  1091.704114
# 1           low   927.857979

# %%
result1.groupby(["product_class"])["profit"].mean().reset_index().sort_values(by=["profit"],ascending = False)
# Out:
#   product_class      profit
# 2        medium  622.704699
# 1           low  406.867519
# 0          high  370.274286

# %%
result1.groupby(["property_valuation"])["list_price"].mean().reset_index().sort_values(by=["list_price"],ascending = False)
# Out:
#     property_valuation   list_price
# 1                    2  1169.468923
# 3                    4  1149.923215
# 6                    7  1107.940553
# 8                    9  1107.820791
# 9                   10  1106.188175
# 7                    8  1105.216619
# 5                    6  1101.973827
# 10                  11  1101.426970
# 2                    3  1099.968195
# 4                    5  1091.887168
# 11                  12  1089.843059
# 0                    1  1087.051462

# %%
result1.groupby(["property_valuation"])["profit"].mean().reset_index().sort_values(by=["profit"],ascending = False)
# Out:
#     property_valuation      profit
# 1                    2  589.837113
# 3                    4  579.140339
# 5                    6  555.685291
# 8                    9  555.205101
# 0                    1  551.724556
# 6                    7  550.926057
# 11                  12  549.293655
# 2                    3  548.587650
# 7                    8  548.082340
# 9                   10  544.034051
# 4                    5  543.898575
# 10                  11  539.576276

# %%
result2 = result1.copy()

# %%
result2.dropna(how="any",axis=0,inplace=True)

# %%
result2.shape
# Out:
# (12970, 32)

# %%
result2.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
# ...

# %%
result2.to_csv("file_no_missing.csv",index=False)

# %%
result2.groupby(["job_industry_category"])["past_3_years_bike_related_purchases"].mean().reset_index().sort_values(by=["past_3_years_bike_related_purchases"],ascending = False)
# Out:
#   job_industry_category  past_3_years_bike_related_purchases
# 0           Argiculture                            51.766520
# 3                Health                            50.381406
# 7                Retail                            50.178545
# 6              Property                            49.778093
# 4                    IT                            49.582143
# 5         Manufacturing                            49.169085
# 2    Financial Services                            48.722005
# 1         Entertainment                            47.076923
# 8    Telecommunications                            40.567568
